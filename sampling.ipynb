# %%
import pandas as pd
import random

# %%
### Sampling: taking 100000 lines from train.txt
trainfile = 'train.txt'

n = 2847802
s = 500000
skip = sorted(random.sample(xrange(n),n-s))

train = pd.read_csv(trainfile, header = None, sep = '\t', skiprows = skip)

train.head()
# Out:
#    0   1   2                  3   4                5               6   \
# 0   0   6   0  20130606000104450   1  VhLrOxuUPqd63CL  windows_chrome
# 1   0   6   0  20130606000104479   1  VhTO1e57PvkyXWE  windows_chrome
# 2   0   6   0  20130606000104992   1  VhkSO71iPlM6FVc  windows_chrome
# 3   0   6   0  20130606000105660   1  Vhd2Lrz8LQFP3bC      windows_ie
# 4   0   6   0  20130606000105664   1  Vhkr1nT2OqTLlgC  windows_chrome
#
#               7    8    9                     ...                      \
# 0  113.200.249.*  333  334                    ...
# 1    124.91.42.*   94  100                    ...
# 2    175.1.175.*  201  204                    ...
# 3    110.208.6.*  216  217                    ...
# 4  124.119.231.*  374  376                    ...
#
#                             14   15   16 17 18  19  \
# 0                   2811067692  250  250  2  0   5
# 1  mm_10027070_118039_10308280  160  600  2  1   0
# 2                   3923448949  300  250  1  0   5
# ...

# %%
### Write sampled lines to txt file
train.to_csv('train_sample.txt', sep = '\t', header = None, index = None)
